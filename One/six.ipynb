# %%
from utils import *
import matplotlib.pyplot as plt
twenty = [2.07, 2.14, 2.22, 2.03, 2.21, 2.03, 2.05, 2.18, 2.09, 2.14, 2.11, 2.02]
forty_five = [2.52, 2.15, 2.49, 2.03, 2.37, 2.05, 1.99, 2.42, 2.08, 2.42, 2.29, 2.01]

# %%
#a)
plt.figure(figsize=(10, 6))
plt.plot(twenty, 'bo')
plt.xticks([])
# Out:
# ([], [])

# %%
plt.figure(figsize=(10,6))
plt.plot(forty_five, 'bo')
plt.xticks([])
# Out:
# ([], [])

# %%
plt.figure(figsize=(10, 6))
plt.plot(twenty, 'bo')
plt.plot(forty_five, 'ro')
plt.xticks([])
# Out:
# ([], [])

# %%
#b)
mean(twenty)
# Out:
# 2.1074999999999995

# %%
mean(forty_five)
# Out:
# 2.235
